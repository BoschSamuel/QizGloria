# %%
# -- coding: utf-8 --
# This code is part of Qiskit.
#
# (C) Copyright IBM 2019.
#
# This code is licensed under the Apache License, Version 2.0. You may
# obtain a copy of this license in the LICENSE.txt file in the root directory
# of this source tree or at http://www.apache.org/licenses/LICENSE-2.0.
#
# Any modifications or derivative works of this code must retain this
# copyright notice, and modified files need to carry a notice indicating
# that they have been altered from the originals.

# %%
import torch
from torch.autograd import Function
import torch.optim as optim

# %%
from qiskit import QuantumRegister,QuantumCircuit,ClassicalRegister,execute
from qiskit.circuit import Parameter
from qiskit import Aer
import numpy as np

# %%
from tqdm import tqdm

# %%
from matplotlib import pyplot as plt
from torch.autograd import Function
# %matplotlib inline

# %%
np.random.seed = 42

# %%
def to_numbers(tensor_list):
    num_list = []
    for tensor in tensor_list:
        num_list += [tensor.item()]
    return num_list

class QiskitCircuit_QAOA():
    def __init__(self,shots):
        self.beta = Parameter('Beta')
        self.gamma = Parameter('Gamma')
        self.shots = shots
        
        def create_circuit():
            ckt = QuantumCircuit(2, 2)
            # add mixer part
            ckt.rx(self.beta, 0)
            ckt.rx(self.beta, 1)

            # add H_target part, for each Zi Zj do this
            ckt.cx(0,1)
            ckt.rz(-1*self.gamma, 1)
            ckt.cx(0,1)
            ckt.measure([0,1],[0,1])
            return ckt

        self.circuit = create_circuit()
    
    def energy_expectation(self, counts, shots, i,j, Cij=-1): #calculate expectation for one qubit pair
        expects = 0
        #print(counts)
        for key in counts.keys():
            perc = counts[key]/shots
            check = Cij*(float(key[i])-1/2)*(float(key[j])-1/2)*perc
            expects += check   
        return [expects] 
    
    def bind(self,parameters):
        [self.beta,self.gamma] = parameters
        #print(self.circuit.data)
        self.circuit.data[0][0]._params = to_numbers(parameters)[0:1]
        self.circuit.data[1][0]._params = to_numbers(parameters)[0:1]
        self.circuit.data[3][0]._params = to_numbers(parameters)[1:2]
        return self.circuit
 
    def run(self, i):
        self.bind(i)
        backend = Aer.get_backend('qasm_simulator')
        job_sim = execute(self.circuit,backend,shots=self.shots)
        result_sim = job_sim.result()
        counts = result_sim.get_counts(self.circuit)
        #print(counts)
        return self.energy_expectation(counts, self.shots, 0,1)    
    
class TorchCircuit(Function):    

    @staticmethod
    def forward(ctx, i):
        if not hasattr(ctx, 'QiskitCirc'):
            ctx.QiskitCirc = QiskitCircuit_QAOA(shots=10000)
            
        #print(i[0])    
        exp_value = ctx.QiskitCirc.run(i[0])
        
        result = torch.tensor([exp_value])
        
        ctx.save_for_backward(result, i)
        
        return result
    
    @staticmethod
    def backward(ctx, grad_output):
        eps = 0.01
        
        forward_tensor, i = ctx.saved_tensors    
        input_numbers = to_numbers(i[0])
        
        gradient = []
        
        for k in range(len(input_numbers)):
            input_eps = input_numbers
            input_eps[k] = input_numbers[k] + eps

            exp_value = ctx.QiskitCirc.run(torch.tensor(input_eps))[0]
            result_eps = torch.tensor([exp_value])
            gradient_result = (exp_value - forward_tensor[0][0].item())/eps
            gradient.append(gradient_result)
            
#         print(gradient)
        result = torch.tensor([gradient])
#         print(result)
        #print("test tens size", result.float(), grad_output.float())
        return result.float() * grad_output.float()

# %%
torch.manual_seed(42)

# %%
# x = torch.tensor([np.pi/4, np.pi/4, np.pi/4], requires_grad=True)
x = torch.tensor([[0.3, 0.2]], requires_grad=True)

qc = TorchCircuit.apply
y1 = qc(x)
print(y1)
y1.backward()
print(x.grad)
# Out:
# tensor([[-0.2297]], grad_fn=<TorchCircuitBackward>)
# tensor([[0.3250, 0.1700]])

# %%
qc = TorchCircuit.apply

def cost(x):
    target = -0.25
    expval = qc(x)
    return torch.abs(qc(x).sum() - target) ** 2, expval

x = torch.tensor([[np.pi/4, np.pi/4]], requires_grad=True)
opt = torch.optim.Adam([x], lr=0.1)

num_epoch = 100

loss_list = []
expval_list = []

for i in tqdm(range(num_epoch)):
# for i in range(num_epoch):
    opt.zero_grad()
    loss, expval = cost(x)
    loss.backward()
    opt.step()
    loss_list.append(loss.item())
    expval_list.append(expval.item())
#     print(loss.item())

plt.plot(loss_list)
    
# print(circuit(phi, theta))
# print(cost(x))
# Out:
# 100%|██████████| 100/100 [00:11<00:00,  8.59it/s]

# %% [markdown]
# ### MNIST in pytorch

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
import numpy as np
import torchvision
from torchvision import datasets, transforms

batch_size_train = 1
batch_size_test = 1
learning_rate = 0.01
momentum = 0.5
log_interval = 10

torch.backends.cudnn.enabled = False

transform=torchvision.transforms.Compose([
                               torchvision.transforms.ToTensor()])

mnist_trainset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)

labels = mnist_trainset.targets #get labels
labels = labels.numpy()
idx1 = np.where(labels == 0) #search all zeros
idx2 = np.where(labels == 1) # search all ones
idx = np.concatenate((idx1[0][0:10],idx2[0][0:10])) # concatenate their indices
#idx = idx2
mnist_trainset.targets = labels[idx] 
mnist_trainset.data = mnist_trainset.data[idx]

print(mnist_trainset)

train_loader = torch.utils.data.DataLoader(mnist_trainset, batch_size=batch_size_train, shuffle=True)
# Out:
# Dataset MNIST
#     Number of datapoints: 20
#     Root location: ./data
#     Split: Train
#     StandardTransform
# Transform: Compose(
#                ToTensor()
#            )

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 10, kernel_size=5)
        self.conv2 = nn.Conv2d(10, 20, kernel_size=5)
        self.conv2_drop = nn.Dropout2d()
        self.fc1 = nn.Linear(320, 50)
        self.fc2 = nn.Linear(50, 6)

    def forward(self, x):
        x = F.relu(F.max_pool2d(self.conv1(x), 2))
        x = F.relu(F.max_pool2d(self.conv2_drop(self.conv2(x)), 2))
        x = x.view(-1, 320)
        x = F.relu(self.fc1(x))
        x = F.dropout(x, training=self.training)
        x = self.fc2(x)
        #x = np.pi*F.tanh(x)
        #print(x)
        x = qc(x)
#         print(x)
        x = (x+1)/4
        x = torch.cat((x, 1-x), -1)
        return x
#         return F.softmax(x)

# %%
network = Net()
optimizer = optim.SGD(network.parameters(), lr=learning_rate,
                      momentum=momentum)

# %%
epochs = 100
for epoch in range(epochs):
    total_loss = []
    for batch_idx, (data, target) in enumerate(train_loader):
#         print(batch_idx)
        optimizer.zero_grad()
        output = network(data)
        print(output[0].data, target)
        loss = F.nll_loss(output, target)
#         print(output)
#         print(output[0][1].item(), target.item())
        #print(loss)
        loss.backward()
        optimizer.step()
        total_loss.append(loss.item())
    print(sum(total_loss)/len(total_loss))
# Out:
# tensor([0.3029, 0.6971]) tensor([0])
# tensor([0.2821, 0.7179]) tensor([0])
# tensor([0.2913, 0.7087]) tensor([1])
# tensor([0.2585, 0.7415]) tensor([0])
# tensor([0.2645, 0.7355]) tensor([1])
# tensor([0.3268, 0.6732]) tensor([0])
# tensor([0.2803, 0.7197]) tensor([1])
# tensor([0.3012, 0.6988]) tensor([0])
# tensor([0.3076, 0.6924]) tensor([1])
# tensor([0.2727, 0.7272]) tensor([1])
# tensor([0.2502, 0.7498]) tensor([0])
# tensor([0.2838, 0.7162]) tensor([1])
# tensor([0.2253, 0.7747]) tensor([0])
# tensor([0.2722, 0.7278]) tensor([1])
# tensor([0.2677, 0.7322]) tensor([1])
# tensor([0.2521, 0.7479]) tensor([0])
# tensor([0.2526, 0.7474]) tensor([0])
# tensor([0.2938, 0.7062]) tensor([1])
# tensor([0.3167, 0.6833]) tensor([0])
# tensor([0.3390, 0.6610]) tensor([1])
# -0.49475999623537065
# tensor([0.3458, 0.6543]) tensor([1])
# tensor([0.2742, 0.7258]) tensor([1])
# tensor([0.2515, 0.7485]) tensor([1])
# tensor([0.2414, 0.7585]) tensor([0])
# tensor([0.2740, 0.7261]) tensor([0])
# tensor([0.2729, 0.7271]) tensor([1])
# tensor([0.2689, 0.7311]) tensor([0])
# tensor([0.2255, 0.7745]) tensor([0])
# tensor([0.2703, 0.7297]) tensor([1])
# tensor([0.3216, 0.6783]) tensor([0])
# tensor([0.2780, 0.7220]) tensor([1])
# tensor([0.2876, 0.7124]) tensor([0])
# tensor([0.2446, 0.7554]) tensor([0])
# tensor([0.2472, 0.7528]) tensor([1])
# tensor([0.3785, 0.6215]) tensor([0])
# tensor([0.2926, 0.7074]) tensor([0])
# tensor([0.2668, 0.7332]) tensor([1])
# tensor([0.2734, 0.7266]) tensor([1])
# tensor([0.2716, 0.7284]) tensor([1])
# tensor([0.2997, 0.7003]) tensor([0])
# -0.5041549995541572
# tensor([0.2607, 0.7393]) tensor([1])
# tensor([0.2738, 0.7262]) tensor([1])
# tensor([0.2670, 0.7330]) tensor([1])
# tensor([0.3813, 0.6187]) tensor([0])
# tensor([0.2443, 0.7557]) tensor([0])
# tensor([0.4369, 0.5631]) tensor([0])
# tensor([0.2677, 0.7322]) tensor([1])
# tensor([0.2348, 0.7652]) tensor([0])
# tensor([0.3557, 0.6443]) tensor([0])
# tensor([0.4701, 0.5299]) tensor([1])
# tensor([0.4665, 0.5335]) tensor([0])
# tensor([0.2154, 0.7846]) tensor([1])
# tensor([0.1999, 0.8001]) tensor([0])
# tensor([0.2712, 0.7288]) tensor([1])
# tensor([0.2603, 0.7398]) tensor([1])
# tensor([0.0422, 0.9578]) tensor([0])
# tensor([0.2950, 0.7049]) tensor([0])
# tensor([0.1007, 0.8993]) tensor([1])
# tensor([0.3191, 0.6809]) tensor([1])
# tensor([0.4442, 0.5558]) tensor([0])
# -0.5197499953210354
# tensor([0.2874, 0.7126]) tensor([1])
# tensor([0.2400, 0.7600]) tensor([1])
# tensor([0.2169, 0.7831]) tensor([0])
# tensor([0.2646, 0.7354]) tensor([0])
# tensor([0.2414, 0.7585]) tensor([1])
# tensor([0.2021, 0.7980]) tensor([0])
# tensor([0.2851, 0.7149]) tensor([1])
# tensor([0.3207, 0.6793]) tensor([0])
# tensor([0.2839, 0.7161]) tensor([0])
# tensor([0.3776, 0.6224]) tensor([1])
# tensor([0.2745, 0.7255]) tensor([0])
# tensor([0.2860, 0.7140]) tensor([1])
# tensor([0.2361, 0.7638]) tensor([0])
# tensor([0.2643, 0.7357]) tensor([0])
# tensor([0.2835, 0.7165]) tensor([1])
# tensor([0.2297, 0.7703]) tensor([1])
# tensor([0.2510, 0.7490]) tensor([0])
# tensor([0.2600, 0.7400]) tensor([1])
# tensor([0.2799, 0.7201]) tensor([1])
# tensor([0.2553, 0.7448]) tensor([0])
# -0.489937499165535
# tensor([0.2422, 0.7578]) tensor([1])
# tensor([0.2785, 0.7214]) tensor([1])
# tensor([0.2770, 0.7230]) tensor([0])
# tensor([0.2417, 0.7584]) tensor([0])
# tensor([0.2617, 0.7383]) tensor([1])
# tensor([0.2580, 0.7420]) tensor([0])
# tensor([0.2414, 0.7586]) tensor([0])
# tensor([0.2600, 0.7400]) tensor([1])
# tensor([0.2763, 0.7236]) tensor([0])
# tensor([0.2245, 0.7755]) tensor([0])
# tensor([0.2875, 0.7125]) tensor([0])
# tensor([0.2943, 0.7057]) tensor([0])
# tensor([0.3036, 0.6963]) tensor([0])
# tensor([0.2753, 0.7247]) tensor([1])
# tensor([0.2650, 0.7350]) tensor([1])
# tensor([0.2762, 0.7238]) tensor([0])
# tensor([0.2479, 0.7521]) tensor([1])
# tensor([0.1919, 0.8081]) tensor([1])
# tensor([0.3126, 0.6874]) tensor([1])
# tensor([0.2356, 0.7645]) tensor([1])
# -0.5054825000464916
# tensor([0.3195, 0.6805]) tensor([0])
# tensor([0.2627, 0.7373]) tensor([1])
# tensor([0.2693, 0.7307]) tensor([0])
# tensor([0.1434, 0.8566]) tensor([1])
# tensor([0.3302, 0.6698]) tensor([0])
# tensor([0.2134, 0.7866]) tensor([0])
# tensor([0.3169, 0.6831]) tensor([1])
# tensor([4.9999e-04, 9.9950e-01]) tensor([1])
# tensor([0.3052, 0.6948]) tensor([0])
# tensor([0.0040, 0.9960]) tensor([1])
# tensor([0.3079, 0.6920]) tensor([1])
# tensor([0.3156, 0.6844]) tensor([0])
# tensor([0.2624, 0.7376]) tensor([1])
# tensor([0.2234, 0.7767]) tensor([1])
# tensor([0.1102, 0.8898]) tensor([0])
# tensor([0.4639, 0.5361]) tensor([1])
# tensor([0.2453, 0.7548]) tensor([0])
# tensor([0.2534, 0.7466]) tensor([0])
# tensor([0.3656, 0.6344]) tensor([1])
# tensor([0.2864, 0.7136]) tensor([0])
# -0.5148925013840199
# tensor([0.0209, 0.9791]) tensor([1])
# tensor([0.4787, 0.5213]) tensor([1])
# tensor([0.0373, 0.9627]) tensor([0])
# tensor([0.0434, 0.9566]) tensor([1])
# tensor([0.3025, 0.6975]) tensor([1])
# tensor([0.0123, 0.9877]) tensor([0])
# tensor([0.2378, 0.7622]) tensor([0])
# tensor([0.3616, 0.6385]) tensor([0])
# tensor([0.1598, 0.8402]) tensor([1])
# tensor([0.2448, 0.7552]) tensor([0])
# tensor([0.4454, 0.5546]) tensor([1])
# tensor([0.1669, 0.8332]) tensor([1])
# tensor([0.4957, 0.5043]) tensor([0])
# tensor([0.4005, 0.5995]) tensor([1])
# tensor([0.1274, 0.8726]) tensor([1])
# tensor([0.3638, 0.6362]) tensor([1])
# tensor([0.4708, 0.5293]) tensor([0])
# tensor([0.1688, 0.8313]) tensor([0])
# tensor([0.2735, 0.7265]) tensor([0])
# tensor([0.3882, 0.6119]) tensor([0])
# -0.5090675041079521
# tensor([0.2731, 0.7269]) tensor([0])
# tensor([0.3196, 0.6804]) tensor([0])
# tensor([0.2878, 0.7122]) tensor([0])
# tensor([0.2821, 0.7179]) tensor([1])
# tensor([0.1873, 0.8127]) tensor([0])
# tensor([0.2548, 0.7452]) tensor([0])
# tensor([0.2993, 0.7006]) tensor([0])
# tensor([0.1845, 0.8155]) tensor([1])
# tensor([0.3122, 0.6878]) tensor([1])
# tensor([0.3010, 0.6990]) tensor([1])
# tensor([0.2811, 0.7189]) tensor([0])
# tensor([0.3350, 0.6650]) tensor([1])
# tensor([0.1129, 0.8871]) tensor([0])
# tensor([0.4170, 0.5830]) tensor([1])
# tensor([0.2285, 0.7715]) tensor([1])
# tensor([0.2910, 0.7090]) tensor([1])
# tensor([0.3145, 0.6855]) tensor([1])
# tensor([0.2292, 0.7708]) tensor([0])
# tensor([0.3009, 0.6991]) tensor([1])
# tensor([0.3243, 0.6757]) tensor([0])
# -0.4801399990916252
# tensor([0.2317, 0.7683]) tensor([1])
# tensor([0.2442, 0.7558]) tensor([0])
# tensor([0.2700, 0.7300]) tensor([0])
# tensor([0.2087, 0.7913]) tensor([0])
# tensor([0.2800, 0.7200]) tensor([0])
# tensor([0.0575, 0.9424]) tensor([1])
# tensor([0.2204, 0.7796]) tensor([1])
# tensor([0.2177, 0.7822]) tensor([0])
# tensor([0.3687, 0.6313]) tensor([1])
# tensor([0.3015, 0.6985]) tensor([0])
# tensor([0.3064, 0.6936]) tensor([1])
# tensor([0.3591, 0.6409]) tensor([1])
# tensor([0.3441, 0.6559]) tensor([1])
# tensor([0.2641, 0.7359]) tensor([1])
# tensor([0.2191, 0.7809]) tensor([0])
# tensor([0.3893, 0.6107]) tensor([0])
# tensor([0.2508, 0.7492]) tensor([1])
# tensor([0.3325, 0.6675]) tensor([1])
# tensor([0.2843, 0.7157]) tensor([0])
# tensor([0.4006, 0.5994]) tensor([0])
# -0.5040025003254414
# tensor([0.2386, 0.7614]) tensor([0])
# tensor([0.2579, 0.7421]) tensor([1])
# tensor([0.2715, 0.7285]) tensor([0])
# tensor([0.2713, 0.7287]) tensor([0])
# tensor([0.3227, 0.6773]) tensor([1])
# tensor([0.2622, 0.7378]) tensor([0])
# tensor([0.3101, 0.6899]) tensor([1])
# tensor([0.2873, 0.7127]) tensor([0])
# tensor([0.2777, 0.7223]) tensor([0])
# tensor([0.2879, 0.7121]) tensor([1])
# tensor([0.3717, 0.6284]) tensor([1])
# tensor([0.3097, 0.6903]) tensor([1])
# tensor([0.3964, 0.6036]) tensor([1])
# tensor([0.3044, 0.6956]) tensor([0])
# tensor([0.3880, 0.6120]) tensor([0])
# tensor([0.2957, 0.7043]) tensor([0])
# tensor([0.3027, 0.6973]) tensor([0])
# tensor([0.3400, 0.6600]) tensor([1])
# tensor([0.2927, 0.7073]) tensor([1])
# tensor([0.3215, 0.6785]) tensor([1])
# -0.4844425044953823
# tensor([0.3118, 0.6882]) tensor([1])
# tensor([0.2866, 0.7134]) tensor([1])
# tensor([0.3636, 0.6364]) tensor([0])
# tensor([0.2964, 0.7035]) tensor([0])
# tensor([0.3086, 0.6913]) tensor([1])
# tensor([0.3921, 0.6079]) tensor([0])
# tensor([0.3321, 0.6679]) tensor([0])
# tensor([0.2944, 0.7056]) tensor([1])
# tensor([0.3387, 0.6613]) tensor([0])
# tensor([0.2851, 0.7149]) tensor([0])
# tensor([0.2936, 0.7064]) tensor([1])
# tensor([0.2800, 0.7200]) tensor([1])
# tensor([0.3856, 0.6144]) tensor([1])
# tensor([0.3142, 0.6859]) tensor([1])
# tensor([0.3197, 0.6803]) tensor([0])
# tensor([0.3023, 0.6977]) tensor([0])
# tensor([0.3015, 0.6985]) tensor([1])
# tensor([0.2824, 0.7176]) tensor([0])
# tensor([0.3167, 0.6833]) tensor([1])
# tensor([0.2761, 0.7240]) tensor([0])
# -0.5047850027680397
# tensor([0.2877, 0.7123]) tensor([1])
# tensor([0.3923, 0.6077]) tensor([0])
# tensor([0.3018, 0.6982]) tensor([0])
# tensor([0.2643, 0.7357]) tensor([1])
# tensor([0.2831, 0.7169]) tensor([1])
# tensor([0.4022, 0.5978]) tensor([1])
# tensor([0.2783, 0.7217]) tensor([1])
# tensor([0.2988, 0.7012]) tensor([0])
# tensor([0.2736, 0.7264]) tensor([1])
# tensor([0.2747, 0.7254]) tensor([0])
# tensor([0.2713, 0.7286]) tensor([0])
# tensor([0.2740, 0.7260]) tensor([0])
# tensor([0.2876, 0.7124]) tensor([0])
# tensor([0.3049, 0.6951]) tensor([0])
# tensor([0.2718, 0.7282]) tensor([0])
# tensor([0.2777, 0.7223]) tensor([1])
# tensor([0.2803, 0.7197]) tensor([1])
# tensor([0.3941, 0.6059]) tensor([1])
# tensor([0.3831, 0.6169]) tensor([1])
# tensor([0.2819, 0.7181]) tensor([0])
# -0.4917274996638298
# tensor([0.3002, 0.6998]) tensor([1])
# tensor([0.2862, 0.7138]) tensor([0])
# tensor([0.3419, 0.6581]) tensor([1])
# tensor([0.3060, 0.6940]) tensor([1])
# tensor([0.2826, 0.7175]) tensor([0])
# tensor([0.2840, 0.7160]) tensor([0])
# tensor([0.2901, 0.7099]) tensor([1])
# tensor([0.2916, 0.7084]) tensor([0])
# tensor([0.2790, 0.7211]) tensor([0])
# tensor([0.2766, 0.7234]) tensor([0])
# tensor([0.2691, 0.7309]) tensor([1])
# tensor([0.2712, 0.7288]) tensor([1])
# tensor([0.3000, 0.7000]) tensor([1])
# tensor([0.2965, 0.7035]) tensor([0])
# tensor([0.2906, 0.7094]) tensor([1])
# tensor([0.2973, 0.7027]) tensor([1])
# tensor([0.2933, 0.7067]) tensor([0])
# tensor([0.3101, 0.6899]) tensor([0])
# tensor([0.2797, 0.7203]) tensor([1])
# tensor([0.2851, 0.7149]) tensor([0])
# -0.4969399988651276
# tensor([0.2715, 0.7285]) tensor([0])
# tensor([0.2630, 0.7370]) tensor([0])
# tensor([0.2734, 0.7265]) tensor([1])
# tensor([0.2689, 0.7311]) tensor([0])
# tensor([0.3040, 0.6960]) tensor([0])
# tensor([0.2775, 0.7225]) tensor([1])
# tensor([0.3265, 0.6735]) tensor([0])
# tensor([0.2668, 0.7332]) tensor([0])
# tensor([0.2889, 0.7111]) tensor([1])
# tensor([0.2655, 0.7345]) tensor([1])
# tensor([0.3345, 0.6655]) tensor([1])
# tensor([0.2783, 0.7217]) tensor([0])
# tensor([0.3091, 0.6909]) tensor([1])
# tensor([0.3166, 0.6834]) tensor([0])
# tensor([0.3016, 0.6984]) tensor([1])
# tensor([0.3054, 0.6946]) tensor([1])
# tensor([0.2873, 0.7127]) tensor([0])
# tensor([0.2763, 0.7237]) tensor([1])
# tensor([0.2995, 0.7005]) tensor([0])
# tensor([0.2775, 0.7225]) tensor([1])
# -0.49863748997449875
# tensor([0.2727, 0.7273]) tensor([1])
# tensor([0.2975, 0.7025]) tensor([1])
# tensor([0.2783, 0.7217]) tensor([0])
# tensor([0.3076, 0.6924]) tensor([1])
# tensor([0.2707, 0.7293]) tensor([1])
# tensor([0.2716, 0.7284]) tensor([0])
# tensor([0.2762, 0.7238]) tensor([0])
# tensor([0.2682, 0.7318]) tensor([1])
# tensor([0.2786, 0.7214]) tensor([1])
# tensor([0.2738, 0.7262]) tensor([1])
# tensor([0.2953, 0.7047]) tensor([1])
# tensor([0.2991, 0.7009]) tensor([1])
# tensor([0.2673, 0.7327]) tensor([0])
# tensor([0.2925, 0.7075]) tensor([0])
# tensor([0.3055, 0.6945]) tensor([0])
# tensor([0.3035, 0.6965]) tensor([0])
# tensor([0.2783, 0.7217]) tensor([0])
# tensor([0.2637, 0.7363]) tensor([0])
# tensor([0.3284, 0.6716]) tensor([1])
# tensor([0.2980, 0.7020]) tensor([0])
# -0.49714500159025193
# tensor([0.3142, 0.6858]) tensor([0])
# tensor([0.2869, 0.7132]) tensor([1])
# tensor([0.3207, 0.6793]) tensor([1])
# tensor([0.2837, 0.7163]) tensor([1])
# tensor([0.2790, 0.7211]) tensor([0])
# tensor([0.3311, 0.6689]) tensor([1])
# tensor([0.3191, 0.6809]) tensor([0])
# tensor([0.2718, 0.7283]) tensor([0])
# tensor([0.3111, 0.6889]) tensor([0])
# tensor([0.2675, 0.7326]) tensor([0])
# tensor([0.3115, 0.6885]) tensor([1])
# tensor([0.3148, 0.6852]) tensor([1])
# tensor([0.3255, 0.6745]) tensor([1])
# tensor([0.2862, 0.7138]) tensor([0])
# tensor([0.3170, 0.6830]) tensor([1])
# tensor([0.3079, 0.6921]) tensor([1])
# tensor([0.3182, 0.6818]) tensor([0])
# tensor([0.3291, 0.6709]) tensor([1])
# tensor([0.2939, 0.7061]) tensor([0])
# tensor([0.2860, 0.7140]) tensor([0])
# -0.4909474954009056
# tensor([0.2806, 0.7194]) tensor([0])
# tensor([0.3275, 0.6725]) tensor([1])
# tensor([0.3185, 0.6815]) tensor([0])
# tensor([0.2869, 0.7131]) tensor([1])
# tensor([0.3300, 0.6701]) tensor([1])
# tensor([0.3142, 0.6858]) tensor([0])
# tensor([0.2882, 0.7118]) tensor([0])
# tensor([0.3271, 0.6729]) tensor([1])
# tensor([0.2862, 0.7138]) tensor([1])
# tensor([0.2893, 0.7107]) tensor([1])
# tensor([0.3135, 0.6865]) tensor([1])
# tensor([0.2915, 0.7085]) tensor([1])
# tensor([0.3040, 0.6960]) tensor([0])
# tensor([0.2787, 0.7213]) tensor([1])
# tensor([0.2919, 0.7082]) tensor([0])
# tensor([0.2862, 0.7139]) tensor([1])
# tensor([0.2799, 0.7201]) tensor([0])
# tensor([0.2771, 0.7229]) tensor([0])
# tensor([0.2840, 0.7161]) tensor([0])
# tensor([0.2796, 0.7204]) tensor([0])
# -0.4950500041246414
# tensor([0.3127, 0.6873]) tensor([1])
# tensor([0.3203, 0.6797]) tensor([0])
# tensor([0.2903, 0.7097]) tensor([1])
# tensor([0.3140, 0.6860]) tensor([0])
# tensor([0.3271, 0.6730]) tensor([1])
# tensor([0.3092, 0.6909]) tensor([0])
# tensor([0.2901, 0.7099]) tensor([1])
# tensor([0.3142, 0.6859]) tensor([1])
# tensor([0.3105, 0.6895]) tensor([0])
# tensor([0.2871, 0.7129]) tensor([1])
# tensor([0.3061, 0.6939]) tensor([0])
# tensor([0.2955, 0.7045]) tensor([1])
# tensor([0.3176, 0.6824]) tensor([0])
# tensor([0.2939, 0.7061]) tensor([1])
# tensor([0.3356, 0.6644]) tensor([0])
# tensor([0.3257, 0.6743]) tensor([0])
# tensor([0.3311, 0.6689]) tensor([1])
# tensor([0.2941, 0.7059]) tensor([1])
# tensor([0.2978, 0.7022]) tensor([0])
# tensor([0.3153, 0.6847]) tensor([0])
# -0.5058049991726875
# tensor([0.3279, 0.6721]) tensor([1])
# tensor([0.3325, 0.6675]) tensor([0])
# tensor([0.3306, 0.6694]) tensor([1])
# tensor([0.3244, 0.6756]) tensor([0])
# tensor([0.2993, 0.7007]) tensor([1])
# tensor([0.3357, 0.6643]) tensor([0])
# tensor([0.3092, 0.6908]) tensor([0])
# tensor([0.3370, 0.6630]) tensor([1])
# tensor([0.3129, 0.6871]) tensor([1])
# tensor([0.2937, 0.7063]) tensor([0])
# tensor([0.3079, 0.6921]) tensor([0])
# tensor([0.3385, 0.6615]) tensor([1])
# tensor([0.3200, 0.6800]) tensor([1])
# tensor([0.2934, 0.7066]) tensor([0])
# tensor([0.3156, 0.6844]) tensor([0])
# tensor([0.3220, 0.6780]) tensor([0])
# tensor([0.3442, 0.6558]) tensor([1])
# tensor([0.3181, 0.6819]) tensor([1])
# tensor([0.3482, 0.6518]) tensor([1])
# tensor([0.3379, 0.6622]) tensor([0])
# -0.4947850003838539
# tensor([0.2937, 0.7063]) tensor([0])
# tensor([0.3399, 0.6601]) tensor([1])
# tensor([0.3155, 0.6845]) tensor([0])
# tensor([0.3311, 0.6689]) tensor([0])
# tensor([0.3426, 0.6574]) tensor([1])
# tensor([0.3179, 0.6821]) tensor([1])
# tensor([0.3231, 0.6769]) tensor([1])
# tensor([0.3025, 0.6975]) tensor([0])
# tensor([0.3399, 0.6601]) tensor([0])
# tensor([0.3413, 0.6587]) tensor([1])
# tensor([0.3340, 0.6660]) tensor([0])
# tensor([0.3348, 0.6652]) tensor([1])
# tensor([0.3164, 0.6836]) tensor([1])
# tensor([0.3403, 0.6597]) tensor([1])
# tensor([0.3393, 0.6607]) tensor([1])
# tensor([0.3284, 0.6716]) tensor([0])
# tensor([0.3138, 0.6862]) tensor([1])
# tensor([0.3098, 0.6902]) tensor([0])
# tensor([0.3329, 0.6671]) tensor([0])
# tensor([0.2922, 0.7078]) tensor([0])
# -0.4935275062918663
# tensor([0.3284, 0.6716]) tensor([1])
# tensor([0.3232, 0.6768]) tensor([0])
# tensor([0.3324, 0.6676]) tensor([1])
# tensor([0.3374, 0.6626]) tensor([1])
# tensor([0.3368, 0.6632]) tensor([1])
# tensor([0.3222, 0.6778]) tensor([0])
# tensor([0.3086, 0.6914]) tensor([1])
# tensor([0.3142, 0.6859]) tensor([1])
# tensor([0.2998, 0.7002]) tensor([1])
# tensor([0.2859, 0.7141]) tensor([1])
# tensor([0.2956, 0.7044]) tensor([0])
# tensor([0.3048, 0.6952]) tensor([0])
# tensor([0.3021, 0.6979]) tensor([1])
# tensor([0.2880, 0.7120]) tensor([0])
# tensor([0.2843, 0.7157]) tensor([1])
# tensor([0.3003, 0.6997]) tensor([0])
# tensor([0.3011, 0.6989]) tensor([0])
# tensor([0.2786, 0.7214]) tensor([0])
# tensor([0.2982, 0.7018]) tensor([0])
# tensor([0.2988, 0.7012]) tensor([0])
# -0.4940550044178963
# tensor([0.3163, 0.6837]) tensor([1])
# tensor([0.3022, 0.6977]) tensor([1])
# tensor([0.2929, 0.7071]) tensor([1])
# tensor([0.3217, 0.6783]) tensor([0])
# tensor([0.2946, 0.7054]) tensor([0])
# tensor([0.2901, 0.7099]) tensor([0])
# tensor([0.3325, 0.6675]) tensor([0])
# tensor([0.3256, 0.6744]) tensor([0])
# tensor([0.3426, 0.6574]) tensor([0])
# tensor([0.3343, 0.6657]) tensor([1])
# tensor([0.2990, 0.7010]) tensor([1])
# tensor([0.2977, 0.7023]) tensor([0])
# tensor([0.3168, 0.6832]) tensor([1])
# tensor([0.3340, 0.6660]) tensor([0])
# tensor([0.3007, 0.6993]) tensor([1])
# tensor([0.3058, 0.6942]) tensor([1])
# tensor([0.3279, 0.6721]) tensor([0])
# tensor([0.3130, 0.6870]) tensor([0])
# tensor([0.3228, 0.6773]) tensor([1])
# tensor([0.2965, 0.7035]) tensor([1])
# -0.5046300008893013
# tensor([0.3293, 0.6707]) tensor([0])
# tensor([0.3301, 0.6699]) tensor([0])
# tensor([0.3102, 0.6898]) tensor([1])
# tensor([0.3386, 0.6615]) tensor([0])
# tensor([0.2900, 0.7099]) tensor([0])
# tensor([0.3216, 0.6783]) tensor([0])
# tensor([0.2943, 0.7056]) tensor([1])
# tensor([0.2885, 0.7114]) tensor([0])
# tensor([0.3404, 0.6596]) tensor([1])
# tensor([0.3413, 0.6587]) tensor([0])
# tensor([0.2905, 0.7095]) tensor([0])
# tensor([0.3279, 0.6721]) tensor([0])
# tensor([0.3199, 0.6801]) tensor([0])
# tensor([0.3300, 0.6700]) tensor([1])
# tensor([0.3340, 0.6660]) tensor([1])
# tensor([0.3202, 0.6798]) tensor([1])
# tensor([0.3185, 0.6816]) tensor([1])
# tensor([0.3086, 0.6914]) tensor([1])
# tensor([0.3007, 0.6993]) tensor([1])
# tensor([0.3234, 0.6766]) tensor([1])
# -0.4998899966478348
# tensor([0.2907, 0.7093]) tensor([1])
# tensor([0.2765, 0.7235]) tensor([0])
# tensor([0.3045, 0.6955]) tensor([0])
# tensor([0.2729, 0.7271]) tensor([1])
# tensor([0.3034, 0.6966]) tensor([0])
# tensor([0.2928, 0.7072]) tensor([0])
# tensor([0.2970, 0.7030]) tensor([1])
# tensor([0.2763, 0.7236]) tensor([1])
# tensor([0.2817, 0.7183]) tensor([0])
# tensor([0.2742, 0.7258]) tensor([0])
# tensor([0.2867, 0.7133]) tensor([1])
# tensor([0.2930, 0.7070]) tensor([0])
# tensor([0.2725, 0.7275]) tensor([1])
# tensor([0.2686, 0.7314]) tensor([0])
# tensor([0.2889, 0.7111]) tensor([0])
# tensor([0.2707, 0.7293]) tensor([1])
# tensor([0.2659, 0.7341]) tensor([1])
# tensor([0.3079, 0.6921]) tensor([1])
# tensor([0.2849, 0.7151]) tensor([1])
# tensor([0.2857, 0.7143]) tensor([0])
# -0.5021974951028824
# tensor([0.2709, 0.7291]) tensor([1])
# tensor([0.2915, 0.7085]) tensor([1])
# tensor([0.2663, 0.7337]) tensor([1])
# tensor([0.2871, 0.7129]) tensor([1])
# tensor([0.2758, 0.7242]) tensor([0])
# tensor([0.2884, 0.7116]) tensor([0])
# tensor([0.2928, 0.7072]) tensor([1])
# tensor([0.2832, 0.7168]) tensor([1])
# tensor([0.2889, 0.7111]) tensor([1])
# tensor([0.2553, 0.7448]) tensor([0])
# tensor([0.2751, 0.7249]) tensor([1])
# tensor([0.2805, 0.7195]) tensor([0])
# tensor([0.2867, 0.7133]) tensor([0])
# tensor([0.2932, 0.7068]) tensor([0])
# tensor([0.2596, 0.7404]) tensor([0])
# tensor([0.3069, 0.6931]) tensor([0])
# tensor([0.3116, 0.6884]) tensor([1])
# tensor([0.2774, 0.7226]) tensor([0])
# tensor([0.3072, 0.6928]) tensor([0])
# tensor([0.2913, 0.7087]) tensor([1])
# -0.4986150026321411
# tensor([0.2898, 0.7102]) tensor([0])
# tensor([0.2746, 0.7254]) tensor([1])
# tensor([0.2867, 0.7133]) tensor([0])
# tensor([0.2702, 0.7298]) tensor([1])
# tensor([0.3113, 0.6887]) tensor([0])
# tensor([0.3001, 0.6999]) tensor([1])
# tensor([0.2953, 0.7047]) tensor([0])
# tensor([0.2926, 0.7074]) tensor([1])
# tensor([0.2898, 0.7102]) tensor([0])
# tensor([0.3077, 0.6923]) tensor([1])
# tensor([0.2914, 0.7086]) tensor([0])
# tensor([0.3000, 0.7000]) tensor([1])
# tensor([0.2929, 0.7071]) tensor([1])
# tensor([0.3234, 0.6766]) tensor([1])
# tensor([0.2963, 0.7037]) tensor([0])
# tensor([0.2829, 0.7171]) tensor([1])
# tensor([0.3097, 0.6903]) tensor([1])
# tensor([0.3059, 0.6941]) tensor([0])
# tensor([0.2984, 0.7017]) tensor([0])
# tensor([0.2964, 0.7035]) tensor([0])
# -0.5003600016236305
# tensor([0.3021, 0.6979]) tensor([0])
# tensor([0.3205, 0.6795]) tensor([1])
# tensor([0.3164, 0.6836]) tensor([1])
# tensor([0.3214, 0.6786]) tensor([0])
# tensor([0.2909, 0.7091]) tensor([1])
# tensor([0.2837, 0.7163]) tensor([0])
# tensor([0.2916, 0.7084]) tensor([1])
# tensor([0.2968, 0.7032]) tensor([1])
# tensor([0.2871, 0.7129]) tensor([0])
# tensor([0.2942, 0.7058]) tensor([0])
# tensor([0.2811, 0.7189]) tensor([0])
# tensor([0.2789, 0.7211]) tensor([1])
# tensor([0.2772, 0.7228]) tensor([1])
# tensor([0.2912, 0.7088]) tensor([1])
# tensor([0.2936, 0.7064]) tensor([0])
# tensor([0.2888, 0.7112]) tensor([0])
# tensor([0.3057, 0.6943]) tensor([0])
# tensor([0.2990, 0.7010]) tensor([1])
# tensor([0.2637, 0.7363]) tensor([1])
# tensor([0.2858, 0.7142]) tensor([0])
# -0.5008599996566773
# tensor([0.3047, 0.6953]) tensor([1])
# tensor([0.2734, 0.7265]) tensor([1])
# tensor([0.2808, 0.7192]) tensor([1])
# tensor([0.2827, 0.7173]) tensor([1])
# tensor([0.3167, 0.6833]) tensor([1])
# tensor([0.3054, 0.6946]) tensor([0])
# tensor([0.3034, 0.6966]) tensor([0])
# tensor([0.3106, 0.6894]) tensor([0])
# tensor([0.2721, 0.7279]) tensor([0])
# tensor([0.3245, 0.6755]) tensor([0])
# tensor([0.3088, 0.6912]) tensor([1])
# tensor([0.3130, 0.6870]) tensor([1])
# tensor([0.3393, 0.6607]) tensor([1])
# tensor([0.3052, 0.6948]) tensor([0])
# tensor([0.3241, 0.6759]) tensor([0])
# tensor([0.3092, 0.6908]) tensor([0])
# tensor([0.3137, 0.6863]) tensor([1])
# tensor([0.3249, 0.6751]) tensor([1])
# tensor([0.3138, 0.6862]) tensor([0])
# tensor([0.3390, 0.6610]) tensor([0])
# -0.5024674996733666
# tensor([0.2844, 0.7156]) tensor([1])
# tensor([0.3108, 0.6892]) tensor([0])
# tensor([0.3165, 0.6835]) tensor([0])
# tensor([0.3262, 0.6738]) tensor([1])
# tensor([0.3230, 0.6770]) tensor([0])
# tensor([0.3220, 0.6780]) tensor([0])
# tensor([0.3356, 0.6644]) tensor([0])
# tensor([0.2987, 0.7013]) tensor([1])
# tensor([0.3000, 0.7000]) tensor([1])
# tensor([0.3198, 0.6802]) tensor([1])
# tensor([0.3521, 0.6479]) tensor([0])
# tensor([0.2912, 0.7088]) tensor([1])
# tensor([0.3241, 0.6759]) tensor([1])
# tensor([0.3306, 0.6694]) tensor([1])
# tensor([0.3442, 0.6558]) tensor([0])
# tensor([0.2959, 0.7041]) tensor([0])
# tensor([0.3409, 0.6591]) tensor([0])
# tensor([0.3367, 0.6633]) tensor([1])
# tensor([0.3542, 0.6458]) tensor([0])
# tensor([0.3269, 0.6731]) tensor([1])
# -0.5078400045633316
# tensor([0.3004, 0.6996]) tensor([0])
# tensor([0.3390, 0.6610]) tensor([1])
# tensor([0.3304, 0.6696]) tensor([0])
# tensor([0.3546, 0.6453]) tensor([0])
# tensor([0.3593, 0.6407]) tensor([1])
# tensor([0.3539, 0.6461]) tensor([0])
# tensor([0.2943, 0.7056]) tensor([0])
# tensor([0.3561, 0.6439]) tensor([0])
# tensor([0.2955, 0.7045]) tensor([1])
# tensor([0.3337, 0.6663]) tensor([1])
# tensor([0.3532, 0.6468]) tensor([1])
# tensor([0.3446, 0.6554]) tensor([1])
# tensor([0.2784, 0.7216]) tensor([0])
# tensor([0.3414, 0.6586]) tensor([1])
# tensor([0.3356, 0.6644]) tensor([1])
# tensor([0.3016, 0.6984]) tensor([0])
# tensor([0.2835, 0.7165]) tensor([0])
# tensor([0.3177, 0.6823]) tensor([0])
# tensor([0.3266, 0.6733]) tensor([1])
# tensor([0.3315, 0.6685]) tensor([1])
# -0.4905224978923798
# tensor([0.3149, 0.6852]) tensor([1])
# tensor([0.3066, 0.6934]) tensor([1])
# tensor([0.2819, 0.7182]) tensor([1])
# tensor([0.3278, 0.6722]) tensor([1])
# tensor([0.3287, 0.6713]) tensor([1])
# tensor([0.3217, 0.6783]) tensor([1])
# tensor([0.2706, 0.7294]) tensor([0])
# tensor([0.3040, 0.6960]) tensor([1])
# tensor([0.2955, 0.7046]) tensor([0])
# tensor([0.2989, 0.7011]) tensor([0])
# tensor([0.2962, 0.7038]) tensor([0])
# tensor([0.3237, 0.6762]) tensor([1])
# tensor([0.3178, 0.6822]) tensor([1])
# tensor([0.2968, 0.7032]) tensor([0])
# tensor([0.3212, 0.6788]) tensor([0])
# tensor([0.3032, 0.6968]) tensor([0])
# tensor([0.3012, 0.6988]) tensor([1])
# tensor([0.2819, 0.7181]) tensor([0])
# tensor([0.2972, 0.7028]) tensor([0])
# tensor([0.2916, 0.7084]) tensor([0])
# -0.4912350013852119
# tensor([0.3042, 0.6958]) tensor([1])
# tensor([0.3099, 0.6901]) tensor([1])
# tensor([0.3073, 0.6927]) tensor([1])
# tensor([0.2794, 0.7206]) tensor([0])
# tensor([0.2650, 0.7350]) tensor([1])
# tensor([0.2758, 0.7242]) tensor([1])
# tensor([0.2819, 0.7181]) tensor([0])
# tensor([0.2883, 0.7117]) tensor([0])
# tensor([0.2891, 0.7110]) tensor([1])
# tensor([0.2742, 0.7258]) tensor([0])
# tensor([0.2860, 0.7140]) tensor([0])
# tensor([0.2758, 0.7242]) tensor([0])
# tensor([0.2918, 0.7082]) tensor([1])
# tensor([0.2799, 0.7201]) tensor([0])
# tensor([0.2734, 0.7266]) tensor([0])
# tensor([0.2760, 0.7240]) tensor([0])
# tensor([0.2961, 0.7039]) tensor([1])
# tensor([0.2871, 0.7128]) tensor([0])
# tensor([0.2816, 0.7184]) tensor([1])
# tensor([0.2883, 0.7117]) tensor([1])
# -0.49464499950408936
# tensor([0.2856, 0.7144]) tensor([1])
# tensor([0.2734, 0.7266]) tensor([1])
# tensor([0.2882, 0.7118]) tensor([0])
# tensor([0.2885, 0.7115]) tensor([1])
# tensor([0.2659, 0.7341]) tensor([1])
# tensor([0.2773, 0.7227]) tensor([1])
# tensor([0.2785, 0.7215]) tensor([0])
# tensor([0.2749, 0.7250]) tensor([0])
# tensor([0.2707, 0.7293]) tensor([1])
# tensor([0.2731, 0.7269]) tensor([1])
# tensor([0.2642, 0.7358]) tensor([0])
# tensor([0.2648, 0.7352]) tensor([1])
# tensor([0.2519, 0.7481]) tensor([0])
# tensor([0.2600, 0.7400]) tensor([1])
# tensor([0.2640, 0.7360]) tensor([0])
# tensor([0.2528, 0.7472]) tensor([1])
# tensor([0.2569, 0.7430]) tensor([0])
# tensor([0.2661, 0.7339]) tensor([0])
# tensor([0.2768, 0.7232]) tensor([0])
# tensor([0.2735, 0.7265]) tensor([0])
# -0.4991574972867966
# tensor([0.2567, 0.7433]) tensor([1])
# tensor([0.2637, 0.7363]) tensor([1])
# tensor([0.2768, 0.7232]) tensor([0])
# tensor([0.2841, 0.7159]) tensor([0])
# tensor([0.2725, 0.7275]) tensor([1])
# tensor([0.2768, 0.7232]) tensor([1])
# tensor([0.2517, 0.7484]) tensor([0])
# tensor([0.2742, 0.7258]) tensor([0])
# tensor([0.2837, 0.7163]) tensor([0])
# tensor([0.2815, 0.7185]) tensor([1])
# tensor([0.2758, 0.7242]) tensor([1])
# tensor([0.2703, 0.7297]) tensor([0])
# tensor([0.2781, 0.7219]) tensor([0])
# tensor([0.2613, 0.7387]) tensor([0])
# tensor([0.2736, 0.7264]) tensor([1])
# tensor([0.2549, 0.7451]) tensor([0])
# tensor([0.2764, 0.7236]) tensor([1])
# tensor([0.2814, 0.7186]) tensor([0])
# tensor([0.2799, 0.7201]) tensor([1])
# tensor([0.2567, 0.7434]) tensor([1])
# -0.500144998729229
# tensor([0.2824, 0.7176]) tensor([0])
# tensor([0.2822, 0.7178]) tensor([1])
# tensor([0.2794, 0.7206]) tensor([0])
# tensor([0.2652, 0.7348]) tensor([1])
# tensor([0.2592, 0.7408]) tensor([1])
# tensor([0.2634, 0.7365]) tensor([0])
# tensor([0.2612, 0.7388]) tensor([0])
# tensor([0.2657, 0.7343]) tensor([1])
# tensor([0.2808, 0.7192]) tensor([0])
# tensor([0.2687, 0.7313]) tensor([0])
# tensor([0.2781, 0.7219]) tensor([0])
# tensor([0.2591, 0.7408]) tensor([1])
# tensor([0.2801, 0.7199]) tensor([1])
# tensor([0.2592, 0.7408]) tensor([1])
# tensor([0.2829, 0.7171]) tensor([1])
# tensor([0.2682, 0.7318]) tensor([0])
# tensor([0.2919, 0.7081]) tensor([1])
# tensor([0.2815, 0.7185]) tensor([0])
# tensor([0.2812, 0.7189]) tensor([1])
# tensor([0.2836, 0.7164]) tensor([0])
# -0.5010250061750412
# tensor([0.2687, 0.7313]) tensor([1])
# tensor([0.2983, 0.7017]) tensor([0])
# tensor([0.2630, 0.7370]) tensor([1])
# tensor([0.2948, 0.7052]) tensor([1])
# tensor([0.2582, 0.7419]) tensor([0])
# tensor([0.2673, 0.7327]) tensor([0])
# tensor([0.2798, 0.7202]) tensor([1])
# tensor([0.2648, 0.7351]) tensor([1])
# tensor([0.2821, 0.7179]) tensor([0])
# tensor([0.2640, 0.7360]) tensor([0])
# tensor([0.2896, 0.7104]) tensor([0])
# tensor([0.2822, 0.7178]) tensor([1])
# tensor([0.2594, 0.7406]) tensor([0])
# tensor([0.2849, 0.7151]) tensor([0])
# tensor([0.2675, 0.7325]) tensor([1])
# tensor([0.2836, 0.7164]) tensor([0])
# tensor([0.2638, 0.7362]) tensor([1])
# tensor([0.2655, 0.7345]) tensor([1])
# tensor([0.2822, 0.7178]) tensor([1])
# tensor([0.2885, 0.7115]) tensor([0])
# -0.5021575018763542
# tensor([0.2596, 0.7404]) tensor([0])
# tensor([0.2585, 0.7415]) tensor([0])
# tensor([0.2708, 0.7292]) tensor([1])
# tensor([0.2599, 0.7401]) tensor([1])
# tensor([0.2890, 0.7110]) tensor([1])
# tensor([0.2835, 0.7165]) tensor([1])
# tensor([0.2837, 0.7163]) tensor([0])
# tensor([0.2704, 0.7296]) tensor([1])
# tensor([0.2702, 0.7298]) tensor([1])
# tensor([0.2592, 0.7408]) tensor([0])
# tensor([0.2664, 0.7336]) tensor([0])
# tensor([0.2903, 0.7097]) tensor([0])
# tensor([0.2865, 0.7135]) tensor([0])
# tensor([0.2564, 0.7436]) tensor([1])
# tensor([0.2915, 0.7085]) tensor([1])
# tensor([0.2717, 0.7283]) tensor([0])
# tensor([0.2736, 0.7264]) tensor([0])
# tensor([0.2609, 0.7391]) tensor([0])
# tensor([0.2646, 0.7355]) tensor([1])
# tensor([0.2721, 0.7279]) tensor([1])
# -0.49911499917507174
# tensor([0.2952, 0.7048]) tensor([0])
# tensor([0.2742, 0.7258]) tensor([0])
# tensor([0.2975, 0.7025]) tensor([0])
# tensor([0.3009, 0.6991]) tensor([1])
# tensor([0.2911, 0.7089]) tensor([0])
# tensor([0.2939, 0.7061]) tensor([1])
# tensor([0.2942, 0.7058]) tensor([1])
# tensor([0.2875, 0.7125]) tensor([1])
# tensor([0.2679, 0.7321]) tensor([1])
# tensor([0.2661, 0.7340]) tensor([1])
# tensor([0.2600, 0.7400]) tensor([0])
# tensor([0.2654, 0.7346]) tensor([0])
# tensor([0.2648, 0.7352]) tensor([0])
# tensor([0.2636, 0.7364]) tensor([1])
# tensor([0.2917, 0.7083]) tensor([0])
# tensor([0.2687, 0.7313]) tensor([1])
# tensor([0.2908, 0.7092]) tensor([0])
# tensor([0.2847, 0.7153]) tensor([0])
# tensor([0.2586, 0.7414]) tensor([1])
# tensor([0.2918, 0.7082]) tensor([1])
# -0.5011249959468842
# tensor([0.2670, 0.7329]) tensor([1])
# tensor([0.2566, 0.7434]) tensor([0])
# tensor([0.2695, 0.7305]) tensor([1])
# tensor([0.2779, 0.7221]) tensor([0])
# tensor([0.2630, 0.7370]) tensor([0])
# tensor([0.2905, 0.7095]) tensor([1])
# tensor([0.2841, 0.7159]) tensor([1])
# tensor([0.2688, 0.7312]) tensor([0])
# tensor([0.2882, 0.7118]) tensor([0])
# tensor([0.2831, 0.7169]) tensor([0])
# tensor([0.2627, 0.7373]) tensor([1])
# tensor([0.2923, 0.7077]) tensor([1])
# tensor([0.2826, 0.7174]) tensor([0])
# tensor([0.2882, 0.7118]) tensor([1])
# tensor([0.2903, 0.7097]) tensor([1])
# tensor([0.2812, 0.7188]) tensor([0])
# tensor([0.2569, 0.7431]) tensor([1])
# tensor([0.2823, 0.7177]) tensor([0])
# tensor([0.2585, 0.7415]) tensor([1])
# tensor([0.2768, 0.7232]) tensor([0])
# -0.5000275000929832
# tensor([0.2853, 0.7147]) tensor([0])
# tensor([0.2598, 0.7402]) tensor([0])
# tensor([0.2905, 0.7095]) tensor([1])
# tensor([0.2819, 0.7181]) tensor([0])
# tensor([0.2871, 0.7128]) tensor([1])
# tensor([0.2853, 0.7147]) tensor([0])
# tensor([0.2601, 0.7399]) tensor([0])
# tensor([0.2864, 0.7136]) tensor([0])
# tensor([0.2907, 0.7092]) tensor([1])
# tensor([0.2634, 0.7366]) tensor([0])
# tensor([0.2824, 0.7176]) tensor([1])
# tensor([0.2975, 0.7025]) tensor([1])
# tensor([0.2965, 0.7035]) tensor([0])
# tensor([0.2654, 0.7346]) tensor([1])
# tensor([0.2648, 0.7351]) tensor([1])
# tensor([0.2851, 0.7149]) tensor([0])
# tensor([0.2961, 0.7039]) tensor([1])
# tensor([0.2930, 0.7070]) tensor([1])
# tensor([0.2947, 0.7053]) tensor([1])
# tensor([0.2654, 0.7346]) tensor([0])
# -0.4953424945473671
# tensor([0.2883, 0.7117]) tensor([1])
# tensor([0.2971, 0.7029]) tensor([0])
# tensor([0.3004, 0.6996]) tensor([0])
# tensor([0.3004, 0.6996]) tensor([1])
# tensor([0.2695, 0.7305]) tensor([0])
# tensor([0.3029, 0.6970]) tensor([1])
# tensor([0.3078, 0.6922]) tensor([0])
# tensor([0.2643, 0.7357]) tensor([0])
# tensor([0.3014, 0.6986]) tensor([1])
# tensor([0.2962, 0.7038]) tensor([0])
# tensor([0.3021, 0.6979]) tensor([0])
# tensor([0.3022, 0.6977]) tensor([0])
# tensor([0.3020, 0.6980]) tensor([1])
# tensor([0.2622, 0.7378]) tensor([1])
# tensor([0.3019, 0.6981]) tensor([1])
# tensor([0.2614, 0.7386]) tensor([1])
# tensor([0.3058, 0.6942]) tensor([1])
# tensor([0.2979, 0.7021]) tensor([0])
# tensor([0.2997, 0.7003]) tensor([1])
# tensor([0.2921, 0.7079]) tensor([0])
# -0.5001849949359893
# tensor([0.2726, 0.7274]) tensor([0])
# tensor([0.3033, 0.6967]) tensor([0])
# tensor([0.2767, 0.7233]) tensor([1])
# tensor([0.3063, 0.6937]) tensor([0])
# tensor([0.2700, 0.7300]) tensor([1])
# tensor([0.3091, 0.6909]) tensor([1])
# tensor([0.2670, 0.7329]) tensor([1])
# tensor([0.2654, 0.7346]) tensor([0])
# tensor([0.2765, 0.7235]) tensor([1])
# tensor([0.2695, 0.7305]) tensor([0])
# tensor([0.2635, 0.7365]) tensor([0])
# tensor([0.2977, 0.7024]) tensor([1])
# tensor([0.3029, 0.6971]) tensor([0])
# tensor([0.3102, 0.6898]) tensor([1])
# tensor([0.2779, 0.7221]) tensor([1])
# tensor([0.3162, 0.6838]) tensor([0])
# tensor([0.2659, 0.7341]) tensor([1])
# tensor([0.2718, 0.7283]) tensor([0])
# tensor([0.2691, 0.7308]) tensor([1])
# tensor([0.2734, 0.7266]) tensor([0])
# -0.5012349963188172
# tensor([0.2659, 0.7341]) tensor([0])
# tensor([0.2765, 0.7235]) tensor([0])
# tensor([0.2709, 0.7291]) tensor([0])
# tensor([0.2719, 0.7281]) tensor([1])
# tensor([0.2800, 0.7200]) tensor([1])
# tensor([0.2721, 0.7279]) tensor([1])
# tensor([0.3194, 0.6806]) tensor([1])
# tensor([0.2702, 0.7298]) tensor([1])
# tensor([0.2564, 0.7436]) tensor([1])
# tensor([0.3106, 0.6894]) tensor([1])
# tensor([0.2680, 0.7320]) tensor([1])
# tensor([0.2777, 0.7223]) tensor([1])
# tensor([0.2734, 0.7266]) tensor([0])
# tensor([0.2684, 0.7316]) tensor([0])
# tensor([0.3176, 0.6824]) tensor([0])
# tensor([0.3137, 0.6862]) tensor([0])
# tensor([0.3293, 0.6707]) tensor([0])
# tensor([0.3246, 0.6754]) tensor([1])
# tensor([0.2713, 0.7287]) tensor([0])
# tensor([0.2689, 0.7311]) tensor([0])
# -0.5002499997615815
# tensor([0.2737, 0.7263]) tensor([0])
# tensor([0.2700, 0.7300]) tensor([1])
# tensor([0.2758, 0.7242]) tensor([0])
# tensor([0.2752, 0.7248]) tensor([1])
# tensor([0.3296, 0.6704]) tensor([0])
# tensor([0.3331, 0.6669]) tensor([0])
# tensor([0.2819, 0.7182]) tensor([0])
# tensor([0.2827, 0.7173]) tensor([0])
# tensor([0.2875, 0.7125]) tensor([0])
# tensor([0.3395, 0.6605]) tensor([1])
# tensor([0.2940, 0.7060]) tensor([1])
# tensor([0.2799, 0.7200]) tensor([1])
# tensor([0.3199, 0.6801]) tensor([1])
# tensor([0.2790, 0.7210]) tensor([0])
# tensor([0.3174, 0.6826]) tensor([0])
# tensor([0.3202, 0.6798]) tensor([0])
# tensor([0.2731, 0.7269]) tensor([1])
# tensor([0.2766, 0.7234]) tensor([1])
# tensor([0.3318, 0.6682]) tensor([1])
# tensor([0.3237, 0.6763]) tensor([1])
# -0.4998599961400032
# tensor([0.2691, 0.7309]) tensor([0])
# tensor([0.2664, 0.7336]) tensor([0])
# tensor([0.3094, 0.6906]) tensor([1])
# tensor([0.3136, 0.6864]) tensor([1])
# tensor([0.2715, 0.7285]) tensor([0])
# tensor([0.2722, 0.7278]) tensor([1])
# tensor([0.2694, 0.7306]) tensor([1])
# tensor([0.2728, 0.7272]) tensor([1])
# tensor([0.2967, 0.7033]) tensor([1])
# tensor([0.2964, 0.7035]) tensor([1])
# tensor([0.2572, 0.7428]) tensor([0])
# tensor([0.2593, 0.7407]) tensor([0])
# tensor([0.2986, 0.7014]) tensor([0])
# tensor([0.2609, 0.7391]) tensor([0])
# tensor([0.3059, 0.6941]) tensor([0])
# tensor([0.3079, 0.6920]) tensor([1])
# tensor([0.2713, 0.7287]) tensor([0])
# tensor([0.2720, 0.7279]) tensor([1])
# tensor([0.2720, 0.7280]) tensor([1])
# tensor([0.3162, 0.6838]) tensor([0])
# -0.49468999952077863
# tensor([0.2722, 0.7278]) tensor([1])
# tensor([0.2699, 0.7301]) tensor([1])
# tensor([0.3111, 0.6889]) tensor([0])
# tensor([0.3216, 0.6783]) tensor([0])
# tensor([0.3184, 0.6816]) tensor([1])
# tensor([0.3179, 0.6821]) tensor([0])
# tensor([0.2778, 0.7222]) tensor([0])
# tensor([0.2767, 0.7233]) tensor([0])
# tensor([0.3209, 0.6791]) tensor([0])
# tensor([0.2841, 0.7159]) tensor([1])
# tensor([0.2808, 0.7192]) tensor([0])
# tensor([0.3200, 0.6800]) tensor([0])
# tensor([0.3246, 0.6754]) tensor([1])
# tensor([0.2896, 0.7104]) tensor([1])
# tensor([0.2868, 0.7132]) tensor([1])
# tensor([0.3277, 0.6723]) tensor([0])
# tensor([0.2813, 0.7187]) tensor([1])
# tensor([0.2814, 0.7186]) tensor([1])
# tensor([0.3221, 0.6779]) tensor([1])
# tensor([0.3219, 0.6781]) tensor([0])
# -0.5073074966669082
# tensor([0.3245, 0.6755]) tensor([0])
# tensor([0.3228, 0.6772]) tensor([1])
# tensor([0.2882, 0.7118]) tensor([1])
# tensor([0.2790, 0.7210]) tensor([0])
# tensor([0.3309, 0.6691]) tensor([1])
# tensor([0.3240, 0.6760]) tensor([0])
# tensor([0.3245, 0.6755]) tensor([1])
# tensor([0.2815, 0.7185]) tensor([1])
# tensor([0.2756, 0.7243]) tensor([1])
# tensor([0.2785, 0.7215]) tensor([0])
# tensor([0.2725, 0.7275]) tensor([1])
# tensor([0.2789, 0.7211]) tensor([1])
# tensor([0.3128, 0.6872]) tensor([0])
# tensor([0.2707, 0.7293]) tensor([0])
# tensor([0.3183, 0.6817]) tensor([0])
# tensor([0.3174, 0.6826]) tensor([0])
# tensor([0.2815, 0.7185]) tensor([0])
# tensor([0.2815, 0.7185]) tensor([1])
# tensor([0.2675, 0.7325]) tensor([0])
# tensor([0.2695, 0.7305]) tensor([1])
# -0.5024199962615967
# tensor([0.2759, 0.7241]) tensor([0])
# tensor([0.3217, 0.6783]) tensor([1])
# tensor([0.2655, 0.7344]) tensor([1])
# tensor([0.3199, 0.6801]) tensor([0])
# tensor([0.2729, 0.7271]) tensor([0])
# tensor([0.3174, 0.6826]) tensor([1])
# tensor([0.2693, 0.7307]) tensor([1])
# tensor([0.3243, 0.6757]) tensor([1])
# tensor([0.3264, 0.6736]) tensor([1])
# tensor([0.3182, 0.6818]) tensor([0])
# tensor([0.2788, 0.7212]) tensor([0])
# tensor([0.3095, 0.6905]) tensor([0])
# tensor([0.3187, 0.6813]) tensor([1])
# tensor([0.2725, 0.7275]) tensor([1])
# tensor([0.2675, 0.7325]) tensor([0])
# tensor([0.2618, 0.7382]) tensor([0])
# tensor([0.2603, 0.7398]) tensor([1])
# tensor([0.3087, 0.6913]) tensor([0])
# tensor([0.2973, 0.7027]) tensor([1])
# tensor([0.2686, 0.7314]) tensor([0])
# -0.49542499929666517
# tensor([0.3108, 0.6892]) tensor([1])
# tensor([0.3047, 0.6953]) tensor([1])
# tensor([0.2925, 0.7075]) tensor([1])
# tensor([0.3051, 0.6949]) tensor([1])
# tensor([0.2840, 0.7160]) tensor([0])
# tensor([0.2914, 0.7086]) tensor([0])
# tensor([0.2924, 0.7076]) tensor([0])
# tensor([0.2843, 0.7157]) tensor([1])
# tensor([0.2567, 0.7434]) tensor([0])
# tensor([0.2862, 0.7139]) tensor([1])
# tensor([0.2783, 0.7218]) tensor([0])
# tensor([0.2551, 0.7449]) tensor([1])
# tensor([0.2483, 0.7516]) tensor([0])
# tensor([0.2516, 0.7484]) tensor([0])
# tensor([0.2618, 0.7382]) tensor([1])
# tensor([0.2815, 0.7185]) tensor([0])
# tensor([0.2574, 0.7426]) tensor([1])
# tensor([0.2493, 0.7507]) tensor([0])
# tensor([0.2725, 0.7276]) tensor([0])
# tensor([0.2817, 0.7183]) tensor([1])
# -0.4933225005865097
# tensor([0.2498, 0.7502]) tensor([1])
# tensor([0.2766, 0.7234]) tensor([0])
# tensor([0.2474, 0.7526]) tensor([0])
# tensor([0.2752, 0.7248]) tensor([0])
# tensor([0.2776, 0.7224]) tensor([0])
# tensor([0.2873, 0.7127]) tensor([1])
# tensor([0.2824, 0.7176]) tensor([0])
# tensor([0.2697, 0.7303]) tensor([1])
# tensor([0.2756, 0.7243]) tensor([0])
# tensor([0.2766, 0.7234]) tensor([1])
# tensor([0.2877, 0.7123]) tensor([1])
# tensor([0.2842, 0.7158]) tensor([1])
# tensor([0.2763, 0.7236]) tensor([1])
# tensor([0.2763, 0.7236]) tensor([0])
# tensor([0.2775, 0.7225]) tensor([1])
# tensor([0.2455, 0.7545]) tensor([0])
# tensor([0.2673, 0.7327]) tensor([1])
# tensor([0.2348, 0.7652]) tensor([0])
# tensor([0.2419, 0.7581]) tensor([1])
# tensor([0.2321, 0.7679]) tensor([0])
# -0.49526249542832373
# tensor([0.2645, 0.7355]) tensor([0])
# tensor([0.2598, 0.7402]) tensor([1])
# tensor([0.2569, 0.7431]) tensor([1])
# tensor([0.2648, 0.7351]) tensor([0])
# tensor([0.2464, 0.7537]) tensor([1])
# tensor([0.2519, 0.7481]) tensor([1])
# tensor([0.2315, 0.7685]) tensor([0])
# tensor([0.2379, 0.7621]) tensor([1])
# tensor([0.2612, 0.7388]) tensor([1])
# tensor([0.2671, 0.7329]) tensor([0])
# tensor([0.2612, 0.7388]) tensor([0])
# tensor([0.2736, 0.7264]) tensor([1])
# tensor([0.2351, 0.7649]) tensor([1])
# tensor([0.2322, 0.7678]) tensor([0])
# tensor([0.2380, 0.7620]) tensor([0])
# tensor([0.2302, 0.7698]) tensor([0])
# tensor([0.2367, 0.7633]) tensor([1])
# tensor([0.2373, 0.7627]) tensor([0])
# tensor([0.2704, 0.7296]) tensor([0])
# tensor([0.2693, 0.7307]) tensor([1])
# -0.49842250272631644
# tensor([0.2702, 0.7298]) tensor([0])
# tensor([0.2378, 0.7621]) tensor([0])
# tensor([0.2749, 0.7250]) tensor([0])
# tensor([0.2817, 0.7183]) tensor([1])
# tensor([0.2393, 0.7607]) tensor([0])
# tensor([0.2368, 0.7632]) tensor([1])
# tensor([0.2681, 0.7319]) tensor([1])
# tensor([0.2775, 0.7225]) tensor([0])
# tensor([0.2531, 0.7469]) tensor([1])
# tensor([0.2396, 0.7603]) tensor([0])
# tensor([0.2768, 0.7232]) tensor([1])
# tensor([0.2845, 0.7155]) tensor([1])
# tensor([0.2735, 0.7265]) tensor([0])
# tensor([0.2428, 0.7572]) tensor([0])
# tensor([0.2801, 0.7199]) tensor([1])
# tensor([0.2393, 0.7607]) tensor([0])
# tensor([0.2448, 0.7552]) tensor([1])
# tensor([0.2677, 0.7322]) tensor([1])
# tensor([0.2296, 0.7704]) tensor([1])
# tensor([0.2290, 0.7710]) tensor([0])
# -0.4950424939393997
# tensor([0.2763, 0.7237]) tensor([0])
# tensor([0.2828, 0.7171]) tensor([1])
# tensor([0.2737, 0.7263]) tensor([1])
# tensor([0.2296, 0.7704]) tensor([0])
# tensor([0.2596, 0.7404]) tensor([0])
# tensor([0.2324, 0.7676]) tensor([0])
# tensor([0.2535, 0.7465]) tensor([1])
# tensor([0.2350, 0.7650]) tensor([1])
# tensor([0.2542, 0.7458]) tensor([1])
# tensor([0.2256, 0.7744]) tensor([0])
# tensor([0.2588, 0.7412]) tensor([0])
# tensor([0.2564, 0.7436]) tensor([1])
# tensor([0.2281, 0.7718]) tensor([0])
# tensor([0.2266, 0.7734]) tensor([1])
# tensor([0.2578, 0.7422]) tensor([1])
# tensor([0.2607, 0.7393]) tensor([1])
# tensor([0.2359, 0.7642]) tensor([1])
# tensor([0.2262, 0.7738]) tensor([0])
# tensor([0.2162, 0.7838]) tensor([0])
# tensor([0.2394, 0.7606]) tensor([0])
# -0.49277250170707704
# tensor([0.2231, 0.7768]) tensor([1])
# tensor([0.2228, 0.7772]) tensor([1])
# tensor([0.2181, 0.7819]) tensor([0])
# tensor([0.2434, 0.7566]) tensor([1])
# tensor([0.2116, 0.7884]) tensor([0])
# tensor([0.2346, 0.7654]) tensor([1])
# tensor([0.2135, 0.7865]) tensor([0])
# tensor([0.2086, 0.7914]) tensor([0])
# tensor([0.2257, 0.7743]) tensor([1])
# tensor([0.2162, 0.7838]) tensor([0])
# tensor([0.2274, 0.7725]) tensor([0])
# tensor([0.2120, 0.7880]) tensor([0])
# tensor([0.2359, 0.7642]) tensor([0])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-308-b1951ca2956a> in <module>
#      11 #         print(output[0][1].item(), target.item())
#      12         #print(loss)
# ---> 13         loss.backward()
#      14         optimizer.step()
#      15         total_loss.append(loss.item())
#
# ~/anaconda3/envs/qiskit_develop/lib/python3.7/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     116                 products. Defaults to ``False``.
#     117         """
# --> 118         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     119
#     120     def register_hook(self, hook):
#
# ~/anaconda3/envs/qiskit_develop/lib/python3.7/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      91     Variable._execution_engine.run_backward(
#      92         tensors, grad_tensors, retain_graph, create_graph,
# ---> 93         allow_unreachable=True)  # allow_unreachable flag
#      94
#      95
#
# KeyboardInterrupt:
